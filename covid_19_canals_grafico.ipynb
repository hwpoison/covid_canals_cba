# %% [markdown]
# # Covid-19 - Canals Córdoba
#
# Lo siguiente es un gráfico de los datos acerca de los casos activos y fallecidos a causa de la pandemia por el COVID-19 en la localidad de Canals, Córdoba, Argentina.
#
# <img src='https://www.turismocordoba.com.ar/canals/img/img-inicial.jpg' style='width:350px'>
# <img src='https://image.freepik.com/vector-gratis/logotipo-coronavirus-covid-19_144101-372.jpg' style='width:200px;'/>
#
# <center><a style='align:center;font-style:italic'>Fuente de los datos: Municipalidad de Canals y otros</a></center>

# %%
import pandas as pd

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
df = pd.read_csv("registro_covid_n.csv")

# %%
cdf = df[['Fecha', 'C. Activos', 'Fallecidos']]
cdf.dropna()
format_date = lambda d: pd.to_datetime(d).strftime('%d/%m/%Y')

start_date = format_date(cdf['Fecha'][0])
end_date =   format_date(cdf['Fecha'][df.index[-1]])
rng = pd.date_range(start=start_date, end=end_date, periods=len(cdf[['C. Activos']]))

# %%
plt.title("CASOS ACTIVOS A LO LARGO DEL TIEMPO")

plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1)) 
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%m/%y"))
plt.gcf().autofmt_xdate()
plt.plot(rng, cdf[['C. Activos']], color="blue",  label="Casos Positivos")
plt.plot(rng, cdf[['Fallecidos']], color="black", label="Fallecidos")

plt.xticks(rotation=50)
plt.legend()
plt.grid(which='major', linestyle='--')
plt.show()
